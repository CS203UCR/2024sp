# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # Introduction to CS203

# %% [markdown]
# ## To sort or not to sort?
#
# Consider the following code snippet, what the performance looks like when option is set to 1 or 0?

# %%
render_code("calculate_sum.c")
# Out:
# // calculate_sum.c:1-15 (15 lines)
# #ifdef __cplusplus
# extern "C" {
# #endif
# long long calculate_sum(int *data, unsigned int size, int threshold)
# {
#     long long sum=0;
#     for (unsigned i = 0; i < size; ++i) {
#         if (data[i] >= threshold)
#                 sum ++;
#     }
#     return sum;
# }
# #ifdef __cplusplus
# }
# #endif

# %%
render_code("arraySort.cpp")
# Out:
# // arraySort.cpp:1-37 (37 lines)
# #include <algorithm>
# #include <ctime>
# #include <iostream>
# #include <climits>
#
# #ifdef __cplusplus
# extern "C" {
# #endif
# long long calculate_sum(int *data, unsigned int size, int threshold);
# #ifdef __cplusplus
# }
# #endif
#
#
# int main(int argc, char **argv)
# {
#     // generate data
# //    const unsigned arraySize = 262144;
#     int arraySize = atoi(argv[1]);
#     int data[arraySize];
#     long long sum = 0;
#
#     int iterations = atoi(argv[2]);
#     int option = atoi(argv[3]);
#
#     for (unsigned c = 0; c < arraySize; ++c)
#         data[c] = std::rand();
#
#     if(option)
#         std::sort(data, data + arraySize);
#
#     for (unsigned i = 0; i < iterations; ++i) {
#         sum += calculate_sum(data, arraySize, std::rand());
#     }
#     std::cout << "sum = " << sum << std::endl;
# }

# %%
! make clean; make
# Out:
# rm -f madd arraySort bitonic quicksort mm
# gcc madd.c -o madd
# gcc calculate_sum.c -c
# g++ -O0 arraySort.cpp calculate_sum.o -o arraySort
# /usr/local/cuda/bin/nvcc -O3 bitonic.cu -o bitonic
# /usr/local/cuda/bin/nvcc -O3 quicksort.cu -o quicksort
# gcc -O3 mm.c perfstats.o -o mm

# %%
! objdump -D arraySort >& arraySort.dump

# %%
render_code("arraySort.dump")
# Out:
# // arraySort.dump:1-3268 (3268 lines)
#
# arraySort:     file format elf64-x86-64
#
#
# Disassembly of section .interp:
#
# 0000000000000318 <.interp>:
#  318:	2f                   	(bad)
#  319:	6c                   	insb   (%dx),%es:(%rdi)
#  31a:	69 62 36 34 2f 6c 64 	imul   $0x646c2f34,0x36(%rdx),%esp
#  321:	2d 6c 69 6e 75       	sub    $0x756e696c,%eax
#  326:	78 2d                	js     355 <_init-0xcab>
#  328:	78 38                	js     362 <_init-0xc9e>
#  32a:	36 2d 36 34 2e 73    	ss sub $0x732e3436,%eax
#  330:	6f                   	outsl  %ds:(%rsi),(%dx)
#  331:	2e 32 00             	xor    %cs:(%rax),%al
#
# Disassembly of section .note.gnu.property:
#
# 0000000000000338 <.note.gnu.property>:
#  338:	04 00                	add    $0x0,%al
#  33a:	00 00                	add    %al,(%rax)
#  33c:	10 00                	adc    %al,(%rax)
#  33e:	00 00                	add    %al,(%rax)
#  340:	05 00 00 00 47       	add    $0x47000000,%eax
# ...

# %%
! time ./arraySort 262144 1000 1
# Out:
# sum = 127161197
#
# real	0m0.177s
# user	0m0.171s
# sys	0m0.000s

# %%
! time ./arraySort 262144 1000 0
# Out:
# sum = 127161197
#
# real	0m0.615s
# user	0m0.612s
# sys	0m0.000s

# %% [markdown]
# ## Algorithm on GPUs?
# Consider quicksort and bitsort, which performs better on GPUs?
#
# ### Quick sort

# %%
! nvidia-smi -a

# %%
render_code("quicksort.cu", show="quickSortIterative")
# Out:
# // quicksort.cu:62-99 (38 lines)
# void quickSortIterative (float arr[], int l, int h)
# {
#     int lstack[ h - l + 1 ], hstack[ h - l + 1];
#     float *d_d;
#     int top = -1, *d_l, *d_h;
#
#     lstack[ ++top ] = l;
#     hstack[ top ] = h;
#
#     cudaMalloc(&d_d, (h-l+1)*sizeof(float));
#     cudaMemcpy(d_d, arr,(h-l+1)*sizeof(float),cudaMemcpyHostToDevice);
#
#     cudaMalloc(&d_l, (h-l+1)*sizeof(int));
#     cudaMemcpy(d_l, lstack,(h-l+1)*sizeof(int),cudaMemcpyHostToDevice);
#
#     cudaMalloc(&d_h, (h-l+1)*sizeof(int));
#     cudaMemcpy(d_h, hstack,(h-l+1)*sizeof(int),cudaMemcpyHostToDevice);
#     int n_t = 1;
#     int n_b = 1;
#     int n_i = 1;
#     while ( n_i > 0 )
#     {
#         partition<<<n_b,n_t>>>( d_d, d_l, d_h, n_i);
#         int answer;
#         cudaMemcpyFromSymbol(&answer, d_size, sizeof(int), 0, cudaMemcpyDeviceToHost);
#         if (answer < 1024)
#           {
#             n_t = answer;
#           }
#         else
#           {
# ...

# %%
render_code("quicksort.cu", show="partition")

# %% [markdown]
# ### Bitonic sort

# %%
render_code("bitonic.cu", show="bitonic_sort")
# Out:
# // bitonic.cu:80-101 (22 lines)
# void bitonic_sort(float *values)
# {
#   float *dev_values;
#   size_t size = NUM_VALS * sizeof(float);
#
#   cudaMalloc((void**) &dev_values, size);
#   cudaMemcpy(dev_values, values, size, cudaMemcpyHostToDevice);
#
#   dim3 blocks(BLOCKS,1);    /* Number of blocks   */
#   dim3 threads(THREADS,1);  /* Number of threads  */
#
#   int j, k;
#   /* Major step */
#   for (k = 2; k <= NUM_VALS; k <<= 1) {
#     /* Minor step */
#     for (j=k>>1; j>0; j=j>>1) {
#       bitonic_sort_step<<<blocks, threads>>>(dev_values, j, k);
#     }
#   }
#   cudaMemcpy(values, dev_values, size, cudaMemcpyDeviceToHost);
#   cudaFree(dev_values);
# }

# %%
render_code("bitonic.cu", show="bitonic_sort_step")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 render_code("bitonic.cu", show="bitonic_sort_step")
#
# NameError: name 'render_code' is not defined

# %%
! ./bitonic
# Out:
# Elapsed time: 0.544s

# %%
# !./quicksort
# Out:
# Elapsed time: 30.148s

# %% [markdown]
# ## Remember how much time we take on CPU?

# %%
! time ./arraySort 67108864 1 1
# Out:
# /bin/bash: line 1: 3571483 Segmentation fault      (core dumped) ./arraySort 67108864 1 1
#
# real	0m0.075s
# user	0m0.000s
# sys	0m0.004s
